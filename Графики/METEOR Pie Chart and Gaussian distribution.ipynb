# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка данных
df = pd.read_csv('data.csv')

# Функция для группировки и построения графиков
def plot_meteor_by_category(direction):
    # Фильтрация по направлению перевода
    filtered_df = df[df['Направление перевода'] == direction]
    # Группировка по категориям и вычисление среднего значения METEOR
    category_means = filtered_df.groupby('Категория')['METEOR'].mean()
    # Печать значений от меньшего к большему
    print(f"\nСредние значения METEOR по категориям ({direction}) от меньшего к большему:")
    sorted_category_means = category_means.sort_values()
    for category, value in sorted_category_means.items():
        print(f"{category}: {value:.4f}")
    # Построение графика Pie Chart
    plt.figure(figsize=(10, 8))
    sorted_category_means.plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Средние значения METEOR по категориям ({direction})')
    plt.ylabel('')
    plt.show()
    # Построение графика с нормальным распределением (кривой плотности KDE)
    plt.figure(figsize=(10, 6))
    sns.kdeplot(sorted_category_means, shade=True, bw_adjust=1.5)
    plt.title(f'Нормальное распределение METEOR по категориям ({direction})')
    plt.xlabel('METEOR Score')
    plt.ylabel('Density')
    plt.show()

# Построение графиков для EN-RU и RU-EN
plot_meteor_by_category('EN-RU')
plot_meteor_by_category('RU-EN')
# Out:
# Средние значения METEOR по категориям (EN-RU) от меньшего к большему:
# Художественный: 0.2115
# Философия: 0.2272
# Научный: 0.3121
# Юридический: 0.4644
# Журналистика: 0.5326
# C:\Users\PC\AppData\Local\Temp\ipykernel_10120\3994819025.py:27: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_category_means, shade=True, bw_adjust=1.5)
# Средние значения METEOR по категориям (RU-EN) от меньшего к большему:
# Художественный: 0.2378
# Философия: 0.2425
# Научный: 0.3496
# Юридический: 0.4363
# Журналистика: 0.5232
# C:\Users\PC\AppData\Local\Temp\ipykernel_10120\3994819025.py:27: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_category_means, shade=True, bw_adjust=1.5)

# %%
def plot_meteor_by_subcategory(direction):
    # Фильтрация по направлению перевода
    filtered_df = df[df['Направление перевода'] == direction]
    # Группировка по подкатегориям и вычисление среднего значения METEOR
    subcategory_means = filtered_df.groupby('Подкатегория')['METEOR'].mean()
    # Печать значений от меньшего к большему
    print(f"\nСредние значения METEOR по подкатегориям ({direction}) от меньшего к большему:")
    sorted_subcategory_means = subcategory_means.sort_values()
    for subcategory, value in sorted_subcategory_means.items():
        print(f"{subcategory}: {value:.4f}")
    # Построение графика Pie Chart
    plt.figure(figsize=(10, 8))
    sorted_subcategory_means.plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Средние значения METEOR по подкатегориям ({direction})')
    plt.ylabel('')
    plt.show()
    # Построение графика с нормальным распределением (кривой плотности KDE)
    plt.figure(figsize=(10, 6))
    sns.kdeplot(sorted_subcategory_means, shade=True, bw_adjust=1.5)
    plt.title(f'Нормальное распределение METEOR по подкатегориям ({direction})')
    plt.xlabel('METEOR Score')
    plt.ylabel('Density')
    plt.show()

# Построение графиков для EN-RU и RU-EN
plot_meteor_by_subcategory('EN-RU')
plot_meteor_by_subcategory('RU-EN')
# Out:
# Средние значения METEOR по подкатегориям (EN-RU) от меньшего к большему:
# Стихи: 0.1953
# Классика: 0.2179
# Религия: 0.2272
# Физика: 0.2453
# Химия: 0.2983
# Математика: 0.3269
# Медицина: 0.3296
# Биология: 0.3602
# Документ: 0.4644
# Расследования: 0.5182
# Исследования: 0.5470
# C:\Users\PC\AppData\Local\Temp\ipykernel_10120\3229417701.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_subcategory_means, shade=True, bw_adjust=1.5)
# Средние значения METEOR по подкатегориям (RU-EN) от меньшего к большему:
# Классика: 0.2364
# Стихи: 0.2411
# Религия: 0.2425
# Физика: 0.3269
# Химия: 0.3303
# Медицина: 0.3404
# Математика: 0.3410
# Биология: 0.4096
# Документ: 0.4363
# Расследования: 0.5048
# Исследования: 0.5417
# C:\Users\PC\AppData\Local\Temp\ipykernel_10120\3229417701.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_subcategory_means, shade=True, bw_adjust=1.5)

# %%
def plot_meteor_by_document(direction):
    # Фильтрация по направлению перевода
    filtered_df = df[df['Направление перевода'] == direction]
    # Группировка по документам и вычисление среднего значения METEOR
    document_means = filtered_df.groupby('Документ')['METEOR'].mean()
    # Печать значений от меньшего к большему
    print(f"\nСредние значения METEOR по документам ({direction}) от меньшего к большему:")
    sorted_document_means = document_means.sort_values()
    for document, value in sorted_document_means.items():
        print(f"{document}: {value:.4f}")
    # Построение графика Pie Chart
    plt.figure(figsize=(10, 8))
    sorted_document_means.plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Средние значения METEOR по документам ({direction})')
    plt.ylabel('')
    plt.show()
    # Построение графика с нормальным распределением (кривой плотности KDE)
    plt.figure(figsize=(10, 6))
    sns.kdeplot(sorted_document_means, shade=True, bw_adjust=1.5)
    plt.title(f'Нормальное распределение METEOR по документам ({direction})')
    plt.xlabel('METEOR Score')
    plt.ylabel('Density')
    plt.show()

# Построение графиков для EN-RU и RU-EN
plot_meteor_by_document('EN-RU')
plot_meteor_by_document('RU-EN')
# Out:
# Средние значения METEOR по документам (EN-RU) от меньшего к большему:
# Фредерик Хаттон Гетман - Элементы анализа газовых трубок: 0.1552
# Пушкин - Короткое собрание стихов: 0.1621
# Эвклид - Начала: 0.1854
# Джейн Остин - Гордость и предубеждение: 0.1855
# Достоевский - Преступление и наказание: 0.2011
# Коран: 0.2069
# Лев Толстой - Война и мир: 0.2146
# Лев Толстой - Анна Каренина: 0.2176
# Альберт Эйнштейн - Значение теории относительности": 0.2228
# Пушкин - Длинное собрание стихов: 0.2286
# Библия - Псалмы: 0.2322
# Библия - Бытие: 0.2343
# Библия - Евангелие от Иоанна: 0.2353
# Макс Планк - Теория теплового излучения: 0.2678
# Достоевский - Братья Карамазовы: 0.2708
# Джозеф Маклиз - Хирургическая анатомия: 0.2730
# Чарльз Дарвин - Происхождение видов: 0.3028
# Документ-контракт: 0.3371
# Джордж М. Гулд и Уолтер Л. Пайл - Аномалии и курьезы медицины: 0.3862
# Э. С. Рассел - Форма и функция: 0.4175
# Томас Андерсон - Элементы агрохимии: 0.4414
# Анри Пуанкаре - Наука и гипотезы: 0.4684
# Конституция РФ: 0.4800
# Южа - Как живет город власть в котором захватили женщины: 0.4890
# Расследование РБК 2: 0.4896
# New York Times — Las Vegas Shooting: 0.5276
# The Atlantic — My Family Slave: 0.5420
# ESPN – I just wanted to survive: 0.5714
# Расследование РБК 1: 0.5760
# Устав ООН: 0.5762
# C:\Users\PC\AppData\Local\Temp\ipykernel_10120\1431307254.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_document_means, shade=True, bw_adjust=1.5)
# Средние значения METEOR по документам (RU-EN) от меньшего к большему:
# Достоевский - Братья Карамазовы: 0.1592
# Коран: 0.1707
# Достоевский - Преступление и наказание: 0.2097
# Лев Толстой - Война и мир: 0.2249
# Пушкин - Короткое собрание стихов: 0.2343
# Джейн Остин - Гордость и предубеждение: 0.2376
# Пушкин - Длинное собрание стихов: 0.2479
# Макс Планк - Теория теплового излучения: 0.2528
# Библия - Псалмы: 0.2529
# Анри Пуанкаре - Наука и гипотезы: 0.2626
# Библия - Бытие: 0.2681
# Библия - Евангелие от Иоанна: 0.2782
# Фредерик Хаттон Гетман - Элементы анализа газовых трубок: 0.2795
# Джозеф Маклиз - Хирургическая анатомия: 0.2867
# Лев Толстой - Анна Каренина: 0.3505
# Документ-контракт: 0.3632
# Томас Андерсон - Элементы агрохимии: 0.3810
# Южа - Как живет город власть в котором захватили женщины: 0.3812
# Конституция РФ: 0.3871
# Джордж М. Гулд и Уолтер Л. Пайл - Аномалии и курьезы медицины: 0.3942
# Альберт Эйнштейн - Значение теории относительности": 0.4010
# Э. С. Рассел - Форма и функция: 0.4063
# Чарльз Дарвин - Происхождение видов: 0.4129
# Эвклид - Начала: 0.4194
# ESPN – I just wanted to survive: 0.5081
# Расследование РБК 1: 0.5450
# The Atlantic — My Family Slave: 0.5545
# Устав ООН: 0.5587
# New York Times — Las Vegas Shooting: 0.5624
# Расследование РБК 2: 0.5882
# C:\Users\PC\AppData\Local\Temp\ipykernel_10120\1431307254.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_document_means, shade=True, bw_adjust=1.5)
