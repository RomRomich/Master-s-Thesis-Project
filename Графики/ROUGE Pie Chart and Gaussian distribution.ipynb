# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Загрузка данных
df = pd.read_csv('data.csv')

# Функция для группировки и построения графиков
def plot_rouge1_by_category(direction):
    # Фильтрация по направлению перевода
    filtered_df = df[df['Направление перевода'] == direction]
    # Группировка по категориям и вычисление среднего значения ROUGE-1
    category_means = filtered_df.groupby('Категория')['ROUGE-1'].mean()
    # Печать значений от меньшего к большему
    print(f"\nСредние значения ROUGE-1 по категориям ({direction}) от меньшего к большему:")
    sorted_category_means = category_means.sort_values()
    for category, value in sorted_category_means.items():
        print(f"{category}: {value:.4f}")
    # Построение графика Pie Chart
    plt.figure(figsize=(10, 8))
    sorted_category_means.plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Средние значения ROUGE-1 по категориям ({direction})')
    plt.ylabel('')
    plt.show()
    # Построение графика с нормальным распределением (кривой плотности KDE)
    plt.figure(figsize=(10, 6))
    sns.kdeplot(sorted_category_means, shade=True, bw_adjust=1.5)
    plt.title(f'Нормальное распределение ROUGE-1 по категориям ({direction})')
    plt.xlabel('ROUGE-1 Score')
    plt.ylabel('Density')
    plt.show()

# Построение графиков для EN-RU и RU-EN
plot_rouge1_by_category('EN-RU')
plot_rouge1_by_category('RU-EN')
# Out:
# Средние значения ROUGE-1 по категориям (EN-RU) от меньшего к большему:
# Художественный: 0.2508
# Журналистика: 0.3030
# Философия: 0.3321
# Научный: 0.4552
# Юридический: 0.6145
# C:\Users\PC\AppData\Local\Temp\ipykernel_5724\3204609359.py:27: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_category_means, shade=True, bw_adjust=1.5)
# Средние значения ROUGE-1 по категориям (RU-EN) от меньшего к большему:
# Журналистика: 0.2670
# Художественный: 0.3080
# Философия: 0.3889
# Научный: 0.5021
# Юридический: 0.5848
# C:\Users\PC\AppData\Local\Temp\ipykernel_5724\3204609359.py:27: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_category_means, shade=True, bw_adjust=1.5)

# %%
def plot_rouge1_by_subcategory(direction):
    # Фильтрация по направлению перевода
    filtered_df = df[df['Направление перевода'] == direction]
    # Группировка по подкатегориям и вычисление среднего значения ROUGE-1
    subcategory_means = filtered_df.groupby('Подкатегория')['ROUGE-1'].mean()
    # Печать значений от меньшего к большему
    print(f"\nСредние значения ROUGE-1 по подкатегориям ({direction}) от меньшего к большему:")
    sorted_subcategory_means = subcategory_means.sort_values()
    for subcategory, value in sorted_subcategory_means.items():
        print(f"{subcategory}: {value:.4f}")
    # Построение графика Pie Chart
    plt.figure(figsize=(10, 8))
    sorted_subcategory_means.plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Средние значения ROUGE-1 по подкатегориям ({direction})')
    plt.ylabel('')
    plt.show()
    # Построение графика с нормальным распределением (кривой плотности KDE)
    plt.figure(figsize=(10, 6))
    sns.kdeplot(sorted_subcategory_means, shade=True, bw_adjust=1.5)
    plt.title(f'Нормальное распределение ROUGE-1 по подкатегориям ({direction})')
    plt.xlabel('ROUGE-1 Score')
    plt.ylabel('Density')
    plt.show()

# Построение графиков для EN-RU и RU-EN
plot_rouge1_by_subcategory('EN-RU')
plot_rouge1_by_subcategory('RU-EN')
# Out:
# Средние значения ROUGE-1 по подкатегориям (EN-RU) от меньшего к большему:
# Стихи: 0.2221
# Классика: 0.2623
# Расследования: 0.2830
# Исследования: 0.3231
# Религия: 0.3321
# Физика: 0.3515
# Химия: 0.4311
# Медицина: 0.4778
# Математика: 0.4852
# Биология: 0.5304
# Документ: 0.6145
# C:\Users\PC\AppData\Local\Temp\ipykernel_5724\2720191990.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_subcategory_means, shade=True, bw_adjust=1.5)
# Средние значения ROUGE-1 по подкатегориям (RU-EN) от меньшего к большему:
# Расследования: 0.2544
# Исследования: 0.2795
# Стихи: 0.3030
# Классика: 0.3100
# Религия: 0.3889
# Медицина: 0.4739
# Физика: 0.4816
# Химия: 0.4909
# Математика: 0.5205
# Биология: 0.5437
# Документ: 0.5848
# C:\Users\PC\AppData\Local\Temp\ipykernel_5724\2720191990.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_subcategory_means, shade=True, bw_adjust=1.5)

# %%
def plot_rouge1_by_document(direction):
    # Фильтрация по направлению перевода
    filtered_df = df[df['Направление перевода'] == direction]
    # Группировка по документам и вычисление среднего значения ROUGE-1
    document_means = filtered_df.groupby('Документ')['ROUGE-1'].mean()
    # Печать значений от меньшего к большему
    print(f"\nСредние значения ROUGE-1 по документам ({direction}) от меньшего к большему:")
    sorted_document_means = document_means.sort_values()
    for document, value in sorted_document_means.items():
        print(f"{document}: {value:.4f}")
    # Построение графика Pie Chart
    plt.figure(figsize=(10, 8))
    sorted_document_means.plot(kind='pie', autopct='%1.1f%%', startangle=90)
    plt.title(f'Средние значения ROUGE-1 по документам ({direction})')
    plt.ylabel('')
    plt.show()
    # Построение графика с нормальным распределением (кривой плотности KDE)
    plt.figure(figsize=(10, 6))
    sns.kdeplot(sorted_document_means, shade=True, bw_adjust=1.5)
    plt.title(f'Нормальное распределение ROUGE-1 по документам ({direction})')
    plt.xlabel('ROUGE-1 Score')
    plt.ylabel('Density')
    plt.show()

# Построение графиков для EN-RU и RU-EN
plot_rouge1_by_document('EN-RU')
plot_rouge1_by_document('RU-EN')
# Out:
# Средние значения ROUGE-1 по документам (EN-RU) от меньшего к большему:
# Пушкин - Короткое собрание стихов: 0.2004
# Достоевский - Преступление и наказание: 0.2248
# Расследование РБК 2: 0.2423
# Лев Толстой - Война и мир: 0.2425
# Пушкин - Длинное собрание стихов: 0.2437
# Фредерик Хаттон Гетман - Элементы анализа газовых трубок: 0.2448
# Лев Толстой - Анна Каренина: 0.2466
# Южа - Как живет город власть в котором захватили женщины: 0.2610
# Коран: 0.2815
# New York Times — Las Vegas Shooting: 0.2876
# Джейн Остин - Гордость и предубеждение: 0.2887
# Альберт Эйнштейн - Значение теории относительности": 0.3002
# Библия - Евангелие от Иоанна: 0.3033
# Достоевский - Братья Карамазовы: 0.3086
# Эвклид - Начала: 0.3228
# Библия - Псалмы: 0.3265
# ESPN – I just wanted to survive: 0.3377
# The Atlantic — My Family Slave: 0.3440
# Расследование РБК 1: 0.3457
# Макс Планк - Теория теплового излучения: 0.4028
# Библия - Бытие: 0.4170
# Джозеф Маклиз - Хирургическая анатомия: 0.4565
# Документ-контракт: 0.4949
# Джордж М. Гулд и Уолтер Л. Пайл - Аномалии и курьезы медицины: 0.4990
# Чарльз Дарвин - Происхождение видов: 0.5026
# Э. С. Рассел - Форма и функция: 0.5581
# Томас Андерсон - Элементы агрохимии: 0.6174
# Конституция РФ: 0.6380
# Анри Пуанкаре - Наука и гипотезы: 0.6476
# Устав ООН: 0.7106
# C:\Users\PC\AppData\Local\Temp\ipykernel_5724\110781037.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_document_means, shade=True, bw_adjust=1.5)
# Средние значения ROUGE-1 по документам (RU-EN) от меньшего к большему:
# Южа - Как живет город власть в котором захватили женщины: 0.1974
# Достоевский - Братья Карамазовы: 0.2072
# Достоевский - Преступление и наказание: 0.2231
# ESPN – I just wanted to survive: 0.2252
# Расследование РБК 2: 0.2519
# Лев Толстой - Война и мир: 0.2558
# Коран: 0.2832
# Пушкин - Короткое собрание стихов: 0.2835
# New York Times — Las Vegas Shooting: 0.2907
# Расследование РБК 1: 0.3140
# Пушкин - Длинное собрание стихов: 0.3225
# The Atlantic — My Family Slave: 0.3228
# Джейн Остин - Гордость и предубеждение: 0.3688
# Библия - Псалмы: 0.3718
# Макс Планк - Теория теплового излучения: 0.4000
# Фредерик Хаттон Гетман - Элементы анализа газовых трубок: 0.4279
# Джозеф Маклиз - Хирургическая анатомия: 0.4308
# Библия - Бытие: 0.4382
# Библия - Евангелие от Иоанна: 0.4623
# Лев Толстой - Анна Каренина: 0.4950
# Анри Пуанкаре - Наука и гипотезы: 0.5029
# Документ-контракт: 0.5073
# Э. С. Рассел - Форма и функция: 0.5140
# Джордж М. Гулд и Уолтер Л. Пайл - Аномалии и курьезы медицины: 0.5170
# Конституция РФ: 0.5254
# Эвклид - Начала: 0.5382
# Томас Андерсон - Элементы агрохимии: 0.5539
# Альберт Эйнштейн - Значение теории относительности": 0.5632
# Чарльз Дарвин - Происхождение видов: 0.5734
# Устав ООН: 0.7218
# C:\Users\PC\AppData\Local\Temp\ipykernel_5724\110781037.py:19: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(sorted_document_means, shade=True, bw_adjust=1.5)
